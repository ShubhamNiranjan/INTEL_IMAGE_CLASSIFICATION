# %%
from keras.models import load_model
model=load_model('model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
class_dirs=['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']
print(class_dirs)
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
import os
import numpy as np
from keras.preprocessing import image

def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(150, 150))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    return img_array/255.,img

# %%
import matplotlib.pyplot as plt
img_dir = r"\Test_the_Intel"

img_files = [os.path.join(img_dir, f) for f in os.listdir(img_dir) if f.endswith(('jpg', 'jpeg', 'png'))]

for img_path in img_files:
    img_array,img=preprocess_image(img_path)
    predictions = model.predict(img_array)
    predicted_label = class_dirs[np.argmax(predictions, axis=1)[0]]
    plt.imshow(img)
    plt.axis('off')
    plt.show()
    print('The provided object is ', predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# The provided object is  buildings
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# The provided object is  street
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# The provided object is  forest
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# The provided object is  forest
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# The provided object is  glacier
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# The provided object is  glacier
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# The provided object is  mountain
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# The provided object is  mountain
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# The provided object is  glacier
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# The provided object is  sea
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# The provided object is  glacier
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# The provided object is  street
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# The provided object is  street
